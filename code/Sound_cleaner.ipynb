# %%
import pandas as pd

# %%
df_1=pd.read_csv("df_coronavirus.csv", names = ['trace_title', 'genre', 'link'])
df_2=pd.read_csv("df_covid.csv")
df_2
# Out:
#                                              trace_title            genre  \
# 0      Can the BCG vaccination protect you from Covid...  News & politics
# 1      "Covid-19 will return in waves - we need a new...  News & politics
# 2      From Perth to Dublin: an Irish doctor comes ho...  News & politics
# 3      Mo Money, Less Problems Tips For Financially S...  News & politics
# 4            Black Women Speak: The Politics of COVID-19  News & politics
# ...                                                  ...              ...
# 16308            Captain Tinrib’s Techno Rave Remix 2020           Techno
# 16309          The Seismic Frequencies LurgCast Volume 4           Techno
# 16310            WATTS GOOD Radio Show #006: Steady Rock           Techno
# 16311                        Verse Podcast 045 : Krushak           Techno
# 16312  Dave Spendley Seismic Frequencies Lurgcast Iso...           Techno
#
#                                                     link
# ...

# %%
df=pd.concat([df_1,df_2])
df
# Out:
#                                              trace_title     genre  \
# 0      Tea With GaryVee #12 | How Coronavirus Will Ch...  Business
# 1      Tea With GaryVee #7 | 14 Ways to Adjust Your L...  Business
# 2               EP3 | Vermijd scherpte met je medewerker  Business
# 3         EP4 | Benut de capaciteit van je team maximaal  Business
# 4      Krishna Memani: Fund Flows In The Times Of Cor...  Business
# ...                                                  ...       ...
# 16308            Captain Tinrib’s Techno Rave Remix 2020    Techno
# 16309          The Seismic Frequencies LurgCast Volume 4    Techno
# 16310            WATTS GOOD Radio Show #006: Steady Rock    Techno
# 16311                        Verse Podcast 045 : Krushak    Techno
# 16312  Dave Spendley Seismic Frequencies Lurgcast Iso...    Techno
#
#                                                     link
# 0      https://soundcloud.com/garyvee/tea-with-garyve...
# ...

# %%
df.drop_duplicates(subset ="link", 
                     keep = False, inplace = True) 
df
# Out:
#                                              trace_title     genre  \
# 0      Tea With GaryVee #12 | How Coronavirus Will Ch...  Business
# 2               EP3 | Vermijd scherpte met je medewerker  Business
# 4      Krishna Memani: Fund Flows In The Times Of Cor...  Business
# 5      Adam Tooze: The World After The Coronavirus Pa...  Business
# 6                         How to WIN Against Coronavirus  Business
# ...                                                  ...       ...
# 16308            Captain Tinrib’s Techno Rave Remix 2020    Techno
# 16309          The Seismic Frequencies LurgCast Volume 4    Techno
# 16310            WATTS GOOD Radio Show #006: Steady Rock    Techno
# 16311                        Verse Podcast 045 : Krushak    Techno
# 16312  Dave Spendley Seismic Frequencies Lurgcast Iso...    Techno
#
#                                                     link
# 0      https://soundcloud.com/garyvee/tea-with-garyve...
# ...

# %%
df.to_csv(r"C:\Users\clara\Desktop\NUOVOSNA\url_nodupl_test.csv", index = False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-629914d6d1c7> in <module>
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined
